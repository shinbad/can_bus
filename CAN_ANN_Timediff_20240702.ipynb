# %% [markdown]
# <a href="https://colab.research.google.com/github/shinbad/can_bus/blob/ANN/CAN_ANN_Timediff_20240702.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Google Drive Mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 데이터 전처리
# - 각 ID별로 Timediff 값 추가
# - 몇 ID가 test데이터에 공격데이터의 수가 부족해 테스트가 안되는 문제가 발생
# - 따라서 디코딩 과정에서 데이터 수가 너무 많아 split했던 data들을 각 ID별로 concat해서 데이터의 양을 늘림
#
#
# ---
# **<데이터 크기로 인한 split 과정>**
# Pre_train_D_1 ->
#   - decoded_can_data_AddDLC_1_0 ->
#       - /filtered_data_AddDLC_1_0/pre_train_D_1_0_ID_{id}   (총 56개)
#   - decoded_can_data_AddDLC_1_1 ->
#       - /filtered_data_AddDLC_1_1/pre_train_D_1_1_ID_{id}   (총 56개)
#
# Pre_train_D_2 ->
#   - decoded_can_data_AddDLC_2_0 ->
#       - /filtered_data_AddDLC_2_0/pre_train_D_2_0_ID_{id}   (총 56개)
#   - decoded_can_data_AddDLC_2_1 ->
#       - /filtered_data_AddDLC_2_1/pre_train_D_2_1_ID_{id}   (총 56개)
#
# => 총 224개의 파일 생성
#
# **<학습을 위한 concat과정>**
#  동일한 id
# combined_df ->
#  - pre_train_D_**1_0**_ID_{id} + pre_train_D_**1_1**_ID_{id} + pre_train_D_**2_0**_ID_{id} + pre_train_D_**2_1**_ID_{id}

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
from sklearn.metrics import classification_report, accuracy_score, f1_score, precision_score, recall_score

# 주어진 ID 리스트
ids = ['251', '2B0', '381', '340', '260', '47F', '329', '164', '387', '394',
       '4F1', '130', '140', '356', '153', '220', '367', '368', '412',
       '470', '38D', '420', '421', '389', '386', '492', '391', '485', '490',
       '593', '484', '48A', '50C', '58B', '436', '541', '507', '4A7', '520',
       '53E', '495', '500', '483', '4A2', '50A', '043', '52A', '544',
       '559', '410', '07F', '57F', '5B0']

       # 366, 563, 553

# 빈도수 분포; ID 별 메시지 TimeDelta 값(ms)
can_freqs = {'000': 2.0,
      '043': 1.0, '07F': 1.0, '130': 0.01, '140': 0.01, '153': 0.01, '164': 0.01, '220': 0.01, '251': 0.01,
      '260': 0.01, '2B0': 0.01, '329': 0.01, '340': 0.01, '356': 0.01, '366': 0.01, '367': 0.01, '368': 0.01, '381': 0.02,
      '386': 0.02, '387': 0.02, '389': 0.02, '38D': 0.02, '391': 0.02, '394': 0.02, '410': 0.2, '412': 0.2, '420': 0.02,
      '421': 0.02, '42D': 0.1, '436': 0.05, '44E': 0.2, '453': 0.02, '470': 0.02, '479': 0.1, '47F': 0.02, '483': 0.2,
      '484': 0.07, '485': 0.05, '48A': 0.05, '48C': 0.2, '490': 0.05, '492': 0.05, '495': 0.1, '49F': 0.2, '4A2': 0.5,
      '4A4': 2.0, '4A7': 0.5, '4A9': 0.2, '4C9': 0.2, '4CB': 0.2, '4F1': 0.02, '500': 0.1, '507': 0.1, '50A': 0.2,
      '50C': 0.1, '50E': 0.2, '520': 0.1, '52A': 0.2, '53B': 0.2, '53E': 0.1, '53F': 0.2, '541': 0.1, '544': 0.2,
      '553': 0.2, '559': 0.2, '563': 0.5, '568': 0.1, '572': 0.2, '57F': 1.5, '58B': 0.05, '593': 0.2, '5A6': 0.2,
      '5B0': 1.0, '5BE': 1.0, '5CD': 0.2, '7C4': 2.0, '7CC': 2.0, '7D0': 2.0, '7D4': 2.0, '7D8': 2.0, '7DC': 2.0 }

# %%
# 데이터 프레임을 저장할 딕셔너리 생성
dfs_by_id_train = {}

# 반복문을 통해 각 ID에 대해 데이터 로드 및 전처리 후 결합하여 딕셔너리에 추가
for id in ids:
    id_dfs = []
    for folder_number in range(1, 3):  # 2개의 폴더를 처리할 것으로 가정
        for j in range(2):  # ID가 0과 1인 두 가지 경우를 처리할 것으로 가정
            file_path = f'/content/drive/MyDrive/CAN/Decoding_data_Timediff_20240627/H-SCOPE/filtered_data_AddDLC_{folder_number}_{j}/pre_train_D_{folder_number}_{j}_ID_{id}.csv'
            try:
                df = pd.read_csv(file_path)
                id_dfs.append(df)
            except FileNotFoundError:
                print(f'File not found: {file_path}')

    if id_dfs:  # id_dfs 리스트가 비어 있지 않은 경우에만 concat
        combined_df = pd.concat(id_dfs, ignore_index=True)

        # TimeDiff 컬럼 추가
        # diff() : 현재 행과 이전 행 차이 계산(timestamp)
        # fillna() : 첫번째 행의 경우 이전행이 없으므로 can_freqs[id]를 이용하여 계산한다.
        combined_df['TimeDiff1'] = ((combined_df['Timestamp'].diff().fillna(can_freqs[id])))
        combined_df['TimeDiff2'] = ((combined_df['Timestamp'].diff(periods=2).fillna(can_freqs[id]*2)))
        combined_df['TimeDiff3'] = ((combined_df['Timestamp'].diff(periods=3).fillna(can_freqs[id]*3)))
        combined_df['TimeDiff4'] = ((combined_df['Timestamp'].diff(periods=4).fillna(can_freqs[id]*4)))
        combined_df['TimeDiff5'] = ((combined_df['Timestamp'].diff(periods=5).fillna(can_freqs[id]*5)))
        combined_df['TimeDiff6'] = ((combined_df['Timestamp'].diff(periods=6).fillna(can_freqs[id]*6)))

        # 객체 타입 컬럼을 카테고리 타입으로 변환
        for col in combined_df.columns:
            if combined_df[col].dtype == 'object':
                combined_df[col] = combined_df[col].astype('category')

        # 모든 값이 0인 경우 제외
        if (combined_df.drop(['Timestamp', 'Arbitration_ID', 'SubClass', 'DLC'], axis=1) == 0).all().all():
            print(f"ID {id}는 모든 값이 0이므로 제외합니다.")
        else:
            dfs_by_id_train[f'df_{id}_combined'] = combined_df

# %%
dfs_by_id_train['df_260_combined']
# Out:
#         Timestamp  Arbitration_ID SubClass  DLC  Checksum   TQI_MIN  \
# 0        0.007005             260   Normal    8       9.0  1.953125
# 1        0.016660             260   Normal    8       8.0  1.953125
# 2        0.026868             260   Normal    8       7.0  1.953125
# 3        0.036675             260   Normal    8      10.0  1.953125
# 4        0.046681             260   Normal    8       9.0  1.953125
# ...           ...             ...      ...  ...       ...       ...
# 66119  167.399959             260   Normal    8       7.0  1.953125
# 66120  167.409276             260   Normal    8       6.0  1.953125
# 66121  167.419839             260   Normal    8       5.0  1.953125
# 66122  167.429246             260   Normal    8       7.0  1.953125
# 66123  167.439230             260   Normal    8       8.0  1.953125
#
#              TQI  TQI_TARGET  GLOW_STAT  CRUISE_LAMP_M  ...  TQI_MAX  \
# 0      20.312500    0.781250        0.0            0.0  ...  73.4375
# 1      20.312500    0.781250        0.0            0.0  ...  73.4375
# 2      20.312500    0.781250        0.0            0.0  ...  73.4375
# 3      20.312500    0.781250        0.0            0.0  ...  73.4375
# 4      20.312500    0.781250        0.0            0.0  ...  73.4375
# ...          ...         ...        ...            ...  ...      ...
# 66119  16.796875    0.000000        0.0            0.0  ...  73.4375
# 66120  16.796875    0.000000        0.0            0.0  ...  73.4375
# 66121  16.796875    0.000000        0.0            0.0  ...  73.4375
# 66122  16.796875    0.390625        0.0            0.0  ...  73.4375
# 66123  16.796875    0.390625        0.0            0.0  ...  73.4375
#
#        SPK_TIME_CUR  AliveCounter  CF_Ems_AclAct  TimeDiff1  TimeDiff2  \
# 0             -2.25           1.0            0.0   0.010000   0.020000
# 1             -2.25           2.0            0.0   0.009655   0.020000
# 2             -2.25           3.0            0.0   0.010208   0.019863
# 3             -2.25           0.0            0.0   0.009807   0.020015
# 4             -2.25           1.0            0.0   0.010006   0.019813
# ...             ...           ...            ...        ...        ...
# 66119         -3.00           1.0            0.0   0.010692   0.019379
# 66120         -3.00           2.0            0.0   0.009317   0.020009
# 66121         -3.00           3.0            0.0   0.010563   0.019880
# 66122         -3.00           0.0            0.0   0.009407   0.019970
# 66123         -3.75           1.0            0.0   0.009984   0.019391
#
#        TimeDiff3  TimeDiff4  TimeDiff5  TimeDiff6
# 0       0.030000   0.040000   0.050000   0.060000
# 1       0.030000   0.040000   0.050000   0.060000
# 2       0.030000   0.040000   0.050000   0.060000
# 3       0.029670   0.040000   0.050000   0.060000
# 4       0.030021   0.039676   0.050000   0.060000
# ...          ...        ...        ...        ...
# 66119   0.030830   0.040898   0.050214   0.060771
# 66120   0.028696   0.040147   0.050215   0.059531
# 66121   0.030572   0.039259   0.050710   0.060778
# 66122   0.029287   0.039979   0.048666   0.060117
# 66123   0.029954   0.039271   0.049963   0.058650
#
# [66124 rows x 25 columns]

# %%
# 데이터 프레임을 저장할 딕셔너리 생성
dfs_by_id_test = {}

# 반복문을 통해 각 ID에 대해 데이터 로드 및 전처리 후 결합하여 딕셔너리에 추가
for id in ids:
    id_dfs = []
    for i in range(0,6):  # 2개의 폴더를 처리할 것으로 가정
        file_path = f'/content/drive/MyDrive/CAN/submit_filter_data/D{i}/pre_test_D_{i}_ID_{id}.csv'
        try:
            df = pd.read_csv(file_path)
            id_dfs.append(df)
        except FileNotFoundError:
            print(f'File not found: {file_path}')

    if id_dfs:  # id_dfs 리스트가 비어 있지 않은 경우에만 concat
        combined_df = pd.concat(id_dfs, ignore_index=True)

        # TimeDiff 컬럼 추가
        # diff() : 현재 행과 이전 행 차이 계산(timestamp)
        # fillna() : 첫번째 행의 경우 이전행이 없으므로 can_freqs[id]를 이용하여 계산한다.
        combined_df['TimeDiff1'] = ((combined_df['Timestamp'].diff().fillna(can_freqs[id])))
        combined_df['TimeDiff2'] = ((combined_df['Timestamp'].diff(periods=2).fillna(can_freqs[id]*2)))
        combined_df['TimeDiff3'] = ((combined_df['Timestamp'].diff(periods=3).fillna(can_freqs[id]*3)))
        combined_df['TimeDiff4'] = ((combined_df['Timestamp'].diff(periods=4).fillna(can_freqs[id]*4)))
        combined_df['TimeDiff5'] = ((combined_df['Timestamp'].diff(periods=5).fillna(can_freqs[id]*5)))
        combined_df['TimeDiff6'] = ((combined_df['Timestamp'].diff(periods=6).fillna(can_freqs[id]*6)))

        # 객체 타입 컬럼을 카테고리 타입으로 변환
        for col in combined_df.columns:
            if combined_df[col].dtype == 'object':
                combined_df[col] = combined_df[col].astype('category')

        # 모든 값이 0인 경우 제외
        if (combined_df.drop(['Timestamp', 'Arbitration_ID', 'SubClass', 'DLC'], axis=1) == 0).all().all():
            print(f"ID {id}는 모든 값이 0이므로 제외합니다.")
        else:
            dfs_by_id_test[f'df_{id}_combined'] = combined_df

# %%
dfs_by_id_test['df_260_combined']
# Out:
#        Timestamp  Arbitration_ID SubClass  DLC   TQI_MIN        TQI  \
# 0       0.000457             260   Normal    8  1.953125  14.843750
# 1       0.010557             260   Normal    8  1.953125  14.843750
# 2       0.020474             260   Normal    8  1.953125  14.843750
# 3       0.030472             260   Normal    8  1.953125  14.843750
# 4       0.040468             260   Normal    8  1.953125  14.843750
# ...          ...             ...      ...  ...       ...        ...
# 77215  96.745680             260   Normal    8  1.953125  18.359375
# 77216  96.755736             260   Normal    8  1.953125  18.359375
# 77217  96.765635             260   Normal    8  1.953125  18.359375
# 77218  96.775676             260   Normal    8  1.953125  18.359375
# 77219  96.785786             260   Normal    8  1.953125  18.359375
#
#        TQI_TARGET  GLOW_STAT  CRUISE_LAMP_M  CRUISE_LAMP_S  ...  SPK_TIME_CUR  \
# 0        0.390625        0.0            0.0            0.0  ...          -3.0
# 1        0.390625        0.0            0.0            0.0  ...          -3.0
# 2        0.390625        0.0            0.0            0.0  ...          -3.0
# 3        0.390625        0.0            0.0            0.0  ...          -3.0
# 4        0.390625        0.0            0.0            0.0  ...          -3.0
# ...           ...        ...            ...            ...  ...           ...
# 77215    3.906250        0.0            0.0            0.0  ...          -6.0
# 77216    3.906250        0.0            0.0            0.0  ...          -6.0
# 77217    3.906250        0.0            0.0            0.0  ...          -6.0
# 77218    3.906250        0.0            0.0            0.0  ...          -6.0
# 77219    3.906250        0.0            0.0            0.0  ...          -6.0
#
#        Checksum  AliveCounter  CF_Ems_AclAct  TimeDiff1  TimeDiff2  TimeDiff3  \
# 0          11.0           2.0            0.0   0.010000   0.020000   0.030000
# 1          10.0           3.0            0.0   0.010100   0.020000   0.030000
# 2          13.0           0.0            0.0   0.009917   0.020017   0.030000
# 3          12.0           1.0            0.0   0.009998   0.019915   0.030015
# 4          11.0           2.0            0.0   0.009996   0.019994   0.029911
# ...         ...           ...            ...        ...        ...        ...
# 77215      14.0           2.0            0.0   0.010021   0.020041   0.029986
# 77216      13.0           3.0            0.0   0.010056   0.020077   0.030097
# 77217       0.0           0.0            0.0   0.009899   0.019955   0.029976
# 77218      15.0           1.0            0.0   0.010041   0.019940   0.029996
# 77219      14.0           2.0            0.0   0.010110   0.020151   0.030050
#
#        TimeDiff4  TimeDiff5  TimeDiff6
# 0       0.040000   0.050000   0.060000
# 1       0.040000   0.050000   0.060000
# 2       0.040000   0.050000   0.060000
# 3       0.040000   0.050000   0.060000
# 4       0.040011   0.050000   0.060000
# ...          ...        ...        ...
# 77215   0.040020   0.049973   0.060064
# 77216   0.040042   0.050076   0.060029
# 77217   0.039996   0.049941   0.059975
# 77218   0.040017   0.050037   0.059982
# 77219   0.040106   0.050127   0.060147
#
# [77220 rows x 25 columns]

# %%
dfs_by_id_test['df_260_combined'].iloc[:,-6:]
# Out:
#        TimeDiff1  TimeDiff2  TimeDiff3  TimeDiff4  TimeDiff5  TimeDiff6
# 0       0.010000   0.020000   0.030000   0.040000   0.050000   0.060000
# 1       0.010100   0.020000   0.030000   0.040000   0.050000   0.060000
# 2       0.009917   0.020017   0.030000   0.040000   0.050000   0.060000
# 3       0.009998   0.019915   0.030015   0.040000   0.050000   0.060000
# 4       0.009996   0.019994   0.029911   0.040011   0.050000   0.060000
# ...          ...        ...        ...        ...        ...        ...
# 77215   0.010021   0.020041   0.029986   0.040020   0.049973   0.060064
# 77216   0.010056   0.020077   0.030097   0.040042   0.050076   0.060029
# 77217   0.009899   0.019955   0.029976   0.039996   0.049941   0.059975
# 77218   0.010041   0.019940   0.029996   0.040017   0.050037   0.059982
# 77219   0.010110   0.020151   0.030050   0.040106   0.050127   0.060147
#
# [77220 rows x 6 columns]

# %% [markdown]
# ## 학습, 테스트 데이터 split & 모델 학습

# %%
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from keras.callbacks import EarlyStopping

# %%
# id별 학습 및 테스트 셋
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf

def id_train_test_set(dfs_by_id_train, dfs_by_id_test, data_id):
    # 데이터프레임 선택
    df_combined_train = dfs_by_id_train[f'df_{data_id}_combined']
    df_combined_test = dfs_by_id_test[f'df_{data_id}_combined']

    train_columns = df_combined_train.columns

    df_combined_test = df_combined_test[train_columns]


    # 타겟 변수와 특징 변수 분리
    X_train = df_combined_train.drop(['SubClass', 'Arbitration_ID'], axis=1)
    y_train = df_combined_train['SubClass']

    X_test = df_combined_test.drop(['SubClass', 'Arbitration_ID'], axis=1)
    y_test = df_combined_test['SubClass']

    categorical_columns = X_train.select_dtypes(include=['category']).columns
    X_train = pd.get_dummies(X_train, columns=categorical_columns)

    categorical_columns = X_test.select_dtypes(include=['category']).columns
    X_test = pd.get_dummies(X_test, columns=categorical_columns)

    cols = X_train.columns
    # 정규화
    scaler = MinMaxScaler()
    X_train.iloc[:,1:-6] = scaler.fit_transform(X_train.iloc[:,1:-6])
    X_train_scaler = X_train.iloc[:,1:-6].astype(np.float32)

    X_test.iloc[:,1:-6] = scaler.transform(X_test.iloc[:,1:-6])
    X_test_scaler = X_test.iloc[:,1:-6].astype(np.float32)

    X_train_df=pd.DataFrame(X_train_scaler, columns=cols)
    X_test_df=pd.DataFrame(X_test_scaler, columns=cols)

    # 클래스 레이블을 숫자로 인코딩
    label_encoder = LabelEncoder()
    y_train_encoded = label_encoder.fit_transform(y_train)
    y_test_encoded = label_encoder.transform(y_test)


    return X_train_scaler, X_test_scaler, y_train_encoded, y_test_encoded, label_encoder.classes_

# %%
def model_train(X_train_ex, X_test_ex, y_train_encoded, y_test_encoded, class_labels):
    # 조기 종료
    early_stopping = EarlyStopping(
          monitor='val_loss',
          patience=5,
          restore_best_weights=True
      )

    # 모델 구축(LSTM)
    #model1
    initializer = "glorot_uniform"
    constraints = None

    model = tf.keras.Sequential([
      tf.keras.layers.Dense(64, input_dim=X_train_ex.shape[1], kernel_initializer=initializer, bias_initializer="zeros", kernel_constraint=constraints, activation='relu'),
      tf.keras.layers.Dense(128, input_dim=X_train_ex.shape[1], kernel_initializer=initializer, bias_initializer="zeros", kernel_constraint=constraints,activation='relu'),
      tf.keras.layers.Dropout(0.3),
      tf.keras.layers.Dense(128, input_dim=X_train_ex.shape[1], kernel_initializer=initializer, bias_initializer="zeros", kernel_constraint=constraints,activation='relu'),
      tf.keras.layers.Dropout(0.3),
      tf.keras.layers.Dense(64, input_dim=X_train_ex.shape[1], kernel_initializer=initializer, bias_initializer="zeros", kernel_constraint=constraints,activation='relu'),
      tf.keras.layers.Dense(len(class_labels),activation='softmax')
      ])

    # 모델 컴파일
    model.compile(loss = 'sparse_categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=['accuracy'])
    # 모델 학습
    training_record = model.fit(X_train_ex, y_train_encoded, epochs=100, batch_size=128,
                                validation_split=0.3, callbacks=[early_stopping],verbose=1, shuffle=False)

    pred = model.predict(X_test_ex)   # 예측
    y_pred = pred.argmax(axis=1)

    # Learning Curve 시각화
    fig, ax = plt.subplots()
    plt.plot(training_record.history["loss"], label="Training Loss")
    plt.plot(training_record.history["val_loss"], label="Validation Loss")
    plt.legend()
    fig.suptitle("Loss")
    plt.show()

    return y_pred

# %% [markdown]
# ## 모델 성능 평가

# %% [markdown]
# ###All ID accuracy test

# %%
from sklearn.metrics import precision_recall_fscore_support, accuracy_score

id_total_results = pd.DataFrame()

for data_id in ids:
    print(f"Processing ID: {data_id}")
    X_train, X_test, y_train, y_test, class_labels = id_train_test_set(dfs_by_id_train, dfs_by_id_test, data_id)
    y_pred = model_train(X_train, X_test, y_train, y_test, class_labels)
    evaluation_results={}

    # 각 모델에 대해 예측을 수행하고 평가 지표를 계산
    # Acccuracy, precision, recall, f1-score 계산
    modelAcc_1= accuracy_score(y_test, y_pred)
    precision, recall, f1_score, support = precision_recall_fscore_support(y_test, y_pred, average='macro', zero_division=1.0)

    # 결과를 딕셔너리에 저장
    evaluation_results[data_id] = {
        'Accuracy': modelAcc_1,
        'Precision': precision,
        'Recall': recall,
        'F1 Score': f1_score
    }

    print('Result:\n')
    print(pd.DataFrame(evaluation_results).T)

    print("\nClassification Report:")
    print(classification_report(y_test, y_pred, target_names=class_labels))

    # 혼동 행렬 계산 및 시각화
    disp = ConfusionMatrixDisplay.from_predictions(y_test, y_pred, display_labels=class_labels, normalize='true', values_format='.0%')

    # 시각화
    plt.title(f'Confusion Matrix for ID: {data_id}')
    #disp.plot(cmap=plt.cm.Blues)
    plt.figure(figsize=(8, 6))
    #cm = confusion_matrix(y_test, y_pred)
    plt.show()
    print("\n" + "="*80 + "\n")

    # 각 아이디별, 모델별 결과 저장
    id_total_results = pd.concat([id_total_results, pd.DataFrame(evaluation_results)], axis=1)
    print("\n" + "="*80 + "\n")
# Out:
# Processing ID: 251
# Epoch 1/100
# 362/362 [==============================] - 3s 6ms/step - loss: 0.1812 - accuracy: 0.9765 - val_loss: 0.1061 - val_accuracy: 0.9802
# Epoch 2/100
# 362/362 [==============================] - 2s 5ms/step - loss: 0.1170 - accuracy: 0.9855 - val_loss: 0.0975 - val_accuracy: 0.9805
# Epoch 3/100
# 362/362 [==============================] - 2s 5ms/step - loss: 0.1017 - accuracy: 0.9856 - val_loss: 0.0961 - val_accuracy: 0.9808
# Epoch 4/100
# 362/362 [==============================] - 3s 8ms/step - loss: 0.0973 - accuracy: 0.9858 - val_loss: 0.0964 - val_accuracy: 0.9809
# Epoch 5/100
# 362/362 [==============================] - 2s 7ms/step - loss: 0.1010 - accuracy: 0.9857 - val_loss: 0.0965 - val_accuracy: 0.9809
# Epoch 6/100
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0944 - accuracy: 0.9859 - val_loss: 0.0955 - val_accuracy: 0.9809
# Epoch 7/100
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0969 - accuracy: 0.9859 - val_loss: 0.0958 - val_accuracy: 0.9809
# Epoch 8/100
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0899 - accuracy: 0.9860 - val_loss: 0.0955 - val_accuracy: 0.9809
# Epoch 9/100
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0866 - accuracy: 0.9860 - val_loss: 0.0951 - val_accuracy: 0.9810
# Epoch 10/100
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0857 - accuracy: 0.9859 - val_loss: 0.0952 - val_accuracy: 0.9809
# Epoch 11/100
# 362/362 [==============================] - 3s 7ms/step - loss: 0.0842 - accuracy: 0.9859 - val_loss: 0.0949 - val_accuracy: 0.9809
# Epoch 12/100
# 362/362 [==============================] - 3s 9ms/step - loss: 0.0833 - accuracy: 0.9860 - val_loss: 0.0939 - val_accuracy: 0.9811
# Epoch 13/100
# 362/362 [==============================] - 3s 9ms/step - loss: 0.0841 - accuracy: 0.9860 - val_loss: 0.0947 - val_accuracy: 0.9808
# Epoch 14/100
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0846 - accuracy: 0.9861 - val_loss: 0.0935 - val_accuracy: 0.9811
# Epoch 15/100
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0856 - accuracy: 0.9860 - val_loss: 0.0940 - val_accuracy: 0.9811
# Epoch 16/100
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0825 - accuracy: 0.9862 - val_loss: 0.0938 - val_accuracy: 0.9811
# Epoch 17/100
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0808 - accuracy: 0.9862 - val_loss: 0.0929 - val_accuracy: 0.9812
# Epoch 18/100
# 362/362 [==============================] - 2s 6ms/step - loss: 0.0799 - accuracy: 0.9862 - val_loss: 0.0934 - val_accuracy: 0.9812
# Epoch 19/100
# 362/362 [==============================] - 3s 9ms/step - loss: 0.0816 - accuracy: 0.9862 - val_loss: 0.0931 - val_accuracy: 0.9813
# Epoch 20/100
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0816 - accuracy: 0.9863 - val_loss: 0.0935 - val_accuracy: 0.9812
# Epoch 21/100
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0787 - accuracy: 0.9863 - val_loss: 0.0940 - val_accuracy: 0.9811
# Epoch 22/100
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0802 - accuracy: 0.9863 - val_loss: 0.0934 - val_accuracy: 0.9813
# 2418/2418 [==============================] - 4s 1ms/step
# Result:
#
#      Accuracy  F1 Score  Precision    Recall
# 251  0.979334  0.659547   0.992085  0.660457
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Fuzzing       1.00      0.98      0.99      1076
#       Normal       0.98      1.00      0.99     74723
#       Replay       0.00      0.00      0.00      1576
#
#     accuracy                           0.98     77375
#    macro avg       0.66      0.66      0.66     77375
# weighted avg       0.96      0.98      0.97     77375
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ================================================================================
#
#
# ================================================================================
#
# Processing ID:
100
# 360/360 [==============================] - 2s 6ms/step - loss: 0.0759 - accuracy: 0.9864 - val_loss: 0.0884 - val_accuracy: 0.9814
# Epoch 14/100
# 360/360 [==============================] - 2s 5ms/step - loss: 0.0854 - accuracy: 0.9860 - val_loss: 0.0914 - val_accuracy: 0.9813
# Epoch 15/100
# 360/360 [==============================] - 2s 5ms/step - loss: 0.0796 - accuracy: 0.9864 - val_loss: 0.0892 - val_accuracy: 0.9815
# Epoch 16/100
# 360/360 [==============================] - 2s 6ms/step - loss: 0.0817 - accuracy: 0.9864 - val_loss: 0.0886 - val_accuracy: 0.9815
# 2399/2399 [==============================] - 5s 2ms/step
# Result:
#
#      Accuracy  F1 Score  Precision    Recall
# 329  0.979399  0.661867   0.993087  0.664062
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Fuzzing       1.00      0.99      1.00       512
#       Normal       0.98      1.00      0.99     74655
#       Replay       0.00      0.00      0.00      1577
#
#     accuracy                           0.98     76744
#    macro avg       0.66      0.66      0.66     76744
# weighted avg       0.96      0.98      0.97     76744
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ================================================================================
#
#
# ================================================================================
#
# Processing ID: 164
# Epoch 1/100
# 362/362 [==============================] - 3s 6ms/step - loss: 0.1930 - accuracy: 0.9531 - val_loss: 0.1148 - val_accuracy: 0.9640
# Epoch 2/100
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0973 - accuracy: 0.9792 - val_loss: 0.0890 - val_accuracy: 0.9816
# Epoch 3/100
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0770 - accuracy: 0.9865 - val_loss: 0.0879 - val_accuracy: 0.9816
# Epoch 4/100
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0769 - accuracy: 0.9865 - val_loss: 0.0855 - val_accuracy: 0.9816
# Epoch 5/100
# 362/362 [==============================] - 3s 8ms/step - loss: 0.0732 - accuracy: 0.9865 - val_loss: 0.0849 - val_accuracy: 0.9816
# Epoch 6/100
# 362/362 [==============================] - 3s 9ms/step - loss: 0.0783 - accuracy: 0.9865 - val_loss: 0.0849 - val_accuracy: 0.9816
# Epoch 7/100
# 362/362 [==============================] - 2s 6ms/step - loss: 0.0741 - accuracy: 0.9865 - val_loss: 0.0846 - val_accuracy: 0.9816
# Epoch 8/100
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0687 - accuracy: 0.9865 - val_loss: 0.0846 - val_accuracy: 0.9815
# Epoch 9/100
# 362/362 [==============================] - 2s 6ms/step - loss: 0.0650 - accuracy: 0.9865 - val_loss: 0.0843 - val_accuracy: 0.9816
# Epoch 10/100
# 362/362 [==============================] - 2s 6ms/step - loss: 0.0631 - accuracy: 0.9865 - val_loss: 0.0843 - val_accuracy: 0.9816
# Epoch 11/100
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0625 - accuracy: 0.9865 - val_loss: 0.0844 - val_accuracy: 0.9816
# Epoch 12/100
# 362/362 [==============================] - 3s 9ms/step - loss: 0.0624 - accuracy: 0.9865 - val_loss: 0.0844 - val_accuracy: 0.9816
# Epoch 13/100
# 362/362 [==============================] - 3s 8ms/step - loss: 0.0636 - accuracy: 0.9865 - val_loss: 0.0846 - val_accuracy: 0.9816
# Epoch 14/100
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0628 - accuracy: 0.9865 - val_loss: 0.0844 - val_accuracy: 0.9816
# Epoch 15/100
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0627 - accuracy: 0.9865 - val_loss: 0.0844 - val_accuracy: 0.9816
# 2416/2416 [==============================] - 5s 2ms/step
# Result:
#
#      Accuracy  F1 Score  Precision    Recall
# 164  0.979612  0.663187   0.993113  0.666667
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Fuzzing       1.00      1.00      1.00      1023
#       Normal       0.98      1.00      0.99     74700
#       Replay       0.00      0.00      0.00      1576
#
#     accuracy                           0.98     77299
#    macro avg       0.66      0.67      0.66     77299
# weighted avg       0.96      0.98      0.97     77299
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ================================================================================
#
#
# ================================================================================
#
# Processing ID: 387
# Epoch 1/100
# 182/182 [==============================] - 2s 7ms/step - loss: 0.2620 - accuracy: 0.9626 - val_loss: 0.1380 - val_accuracy: 0.9631
# Epoch 2/100
# 182/182 [==============================] - 1s 7ms/step - loss: 0.1017 - accuracy: 0.9807 - val_loss: 0.0895 - val_accuracy: 0.9811
# Epoch 3/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.0698 - accuracy: 0.9860 - val_loss: 0.0864 - val_accuracy: 0.9811
# Epoch 4/100
# 182/182 [==============================] - 1s 7ms/step - loss: 0.0584 - accuracy: 0.9860 - val_loss: 0.0801 - val_accuracy: 0.9812
# Epoch 5/100
# 182/182 [==============================] - 2s 9ms/step - loss: 0.0554 - accuracy: 0.9861 - val_loss: 0.0776 - val_accuracy: 0.9811
# Epoch 6/100
# 182/182 [==============================] - 2s 9ms/step - loss: 0.0515 - accuracy: 0.9861 - val_loss: 0.0727 - val_accuracy: 0.9812
# Epoch 7/100
# 182/182 [==============================] - 2s 9ms/step - loss: 0.0494 - accuracy: 0.9861 - val_loss: 0.0678 - val_accuracy: 0.9812
# Epoch 8/100
# 182/182 [==============================] - 2s 9ms/step - loss: 0.0490 - accuracy: 0.9868 - val_loss: 0.0657 - val_accuracy: 0.9863
# Epoch 9/100
# 182/182 [==============================] - 2s 11ms/step - loss: 0.0482 - accuracy: 0.9872 - val_loss: 0.0634 - val_accuracy: 0.9812
# Epoch 10/100
# 182/182 [==============================] - 2s 9ms/step - loss: 0.0453 - accuracy: 0.9869 - val_loss: 0.0598 - val_accuracy: 0.9863
# Epoch 11/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.0431 - accuracy: 0.9892 - val_loss: 0.0573 - val_accuracy: 0.9812
# Epoch 12/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.0411 - accuracy: 0.9874 - val_loss: 0.0581 - val_accuracy: 0.9809
# Epoch 13/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.0399 - accuracy: 0.9905 - val_loss: 0.0558 - val_accuracy: 0.9812
# Epoch 14/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.0366 - accuracy: 0.9875 - val_loss: 0.0503 - val_accuracy: 0.9814
# Epoch 15/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.0425 - accuracy: 0.9899 - val_loss: 0.0599 - val_accuracy: 0.9812
# Epoch 16/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.0344 - accuracy: 0.9884 - val_loss: 0.0511 - val_accuracy: 0.9862
# Epoch 17/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.0320 - accuracy: 0.9900 - val_loss: 0.0461 - val_accuracy: 0.9848
# Epoch 18/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.0286 - accuracy: 0.9908 - val_loss: 0.0478 - val_accuracy: 0.9864
# Epoch 19/100
# 182/182 [==============================] - 1s 6ms/step - loss: 0.0215 - accuracy: 0.9940 - val_loss: 0.0503 - val_accuracy: 0.9812
# Epoch 20/100
# 182/182 [==============================] - 1s 8ms/step - loss: 0.0420 - accuracy: 0.9906 - val_loss: 0.0546 - val_accuracy: 0.9863
# Epoch 21/100
# 182/182 [==============================] - 2s 9ms/step - loss: 0.0264 - accuracy: 0.9920 - val_loss: 0.0489 - val_accuracy: 0.9819
# Epoch 22/100
# 182/182 [==============================] - 2s 10ms/step - loss: 0.0306 - accuracy: 0.9909 - val_loss: 0.0477 - val_accuracy: 0.9865
# 1207/1207 [==============================] - 2s 2ms/step
# Result:
#
#      Accuracy  F1 Score  Precision    Recall
# 387  0.976477  0.741338   0.780321  0.721368
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Fuzzing       1.00      0.99      0.99       512
#       Normal       0.98      0.99      0.99     37300
#       Replay       0.36      0.18      0.24       788
#
#     accuracy                           0.98     38600
#    macro avg       0.78      0.72      0.74     38600
# weighted avg       0.97      0.98      0.97     38600
# ================================================================================
#
#
# ================================================================================
#
# Processing ID: 394
# Epoch 1/100
# 181/181 [==============================] - 2s 8ms/step - loss: 0.2013 - accuracy: 0.9625 - val_loss: 0.0915 - val_accuracy: 0.9811
# Epoch 2/100
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0868 - accuracy: 0.9840 - val_loss: 0.0709 - val_accuracy: 0.9816
# Epoch 3/100
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0590 - accuracy: 0.9864 - val_loss: 0.0498 - val_accuracy: 0.9816
# Epoch 4/100
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0444 - accuracy: 0.9864 - val_loss: 0.0416 - val_accuracy: 0.9817
# Epoch 5/100
# 181/181 [==============================] - 1s 7ms/step - loss: 0.0394 - accuracy: 0.9864 - val_loss: 0.0384 - val_accuracy: 0.9817
# Epoch 6/100
# 181/181 [==============================] - 2s 9ms/step - loss: 0.0364 - accuracy: 0.9864 - val_loss: 0.0370 - val_accuracy: 0.9817
# Epoch 7/100
# 181/181 [==============================] - 2s 9ms/step - loss: 0.0308 - accuracy: 0.9864 - val_loss: 0.0513 - val_accuracy: 0.9817
# Epoch 8/100
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0264 - accuracy: 0.9864 - val_loss: 0.0449 - val_accuracy: 0.9817
# Epoch 9/100
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0261 - accuracy: 0.9796 - val_loss: 0.0368 - val_accuracy: 0.9817
# Epoch 10/100
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0246 - accuracy: 0.9815 - val_loss: 0.0646 - val_accuracy: 0.9817
# Epoch 11/100
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0267 - accuracy: 0.9797 - val_loss: 0.0420 - val_accuracy: 0.9813
# Epoch 12/100
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0238 - accuracy: 0.9846 - val_loss: 0.0784 - val_accuracy: 0.9817
# Epoch 13/100
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0456 - accuracy: 0.9730 - val_loss: 0.0435 - val_accuracy: 0.9817
# Epoch 14/100
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0359 - accuracy: 0.9863 - val_loss: 0.0365 - val_accuracy: 0.9817
# Epoch 15/100
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0239 - accuracy: 0.9864 - val_loss: 0.0723 - val_accuracy: 0.9817
# Epoch 16/100
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0329 - accuracy: 0.9864 - val_loss: 0.0577 - val_accuracy: 0.9817
# Epoch 17/100
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0214 - accuracy: 0.9865 - val_loss: 0.0575 - val_accuracy: 0.9817
# Epoch 18/100
# 181/181 [==============================] - 2s 8ms/step - loss: 0.0208 - accuracy: 0.9865 - val_loss: 0.0608 - val_accuracy: 0.9817
# Epoch 19/100
# 181/181 [==============================] - 2s 9ms/step - loss: 0.0205 - accuracy: 0.9847 - val_loss: 0.0610 - val_accuracy: 0.9817
# 1205/1205 [==============================] - 3s 2ms/step
# Result:
#
#      Accuracy  F1 Score  Precision    Recall
# 394  0.979538  0.662811   0.993099  0.665929
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Fuzzing       1.00      1.00      1.00       452
#       Normal       0.98      1.00      0.99     37319
#       Replay       0.00      0.00      0.00       788
#
#     accuracy                           0.98     38559
#    macro avg       0.66      0.67      0.66     38559
# weighted avg       0.96      0.98      0.97     38559
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ================================================================================
#
#
# ================================================================================
#
# Processing ID: 4F1
# Epoch 1/100
# 181/181 [==============================] - 2s 7ms/step - loss: 0.2447 - accuracy: 0.9647 - val_loss: 0.1130 - val_accuracy: 0.9758
# Epoch 2/100
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0928 - accuracy: 0.9857 - val_loss: 0.0906 - val_accuracy: 0.9816
# Epoch 3/100
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0851 - accuracy: 0.9865 - val_loss: 0.0904 - val_accuracy: 0.9815
# Epoch 4/100
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0781 - accuracy: 0.9864 - val_loss: 0.0918 - val_accuracy: 0.9816
# Epoch 5/100
# 181/181 [==============================] - 1s 6ms/step - loss: 0.0789 - accuracy: 0.9864 - val_loss: 0.0938 - val_accuracy: 0.9816
# Epoch 6/100
# 181/181 [==============================] - 2s 9ms/step - loss: 0.0708 - accuracy: 0.9864 - val_loss: 0.0962 - val_accuracy: 0.9816
# Epoch 7/100
# 181/181 [==============================] - 2s 9ms/step - loss: 0.0693 - accuracy: 0.9865 - val_loss: 0.0983 - val_accuracy: 0.9816
# Epoch 8/100
# 181/181 [==============================] - 2s 10ms/step - loss: 0.0669 - accuracy: 0.9865 - val_loss: 0.0995 - val_accuracy: 0.9816
# 1206/1206 [==============================] - 2s 2ms/step
# Result:
#
#      Accuracy  F1 Score  Precision    Recall
# 4F1  0.979436  0.661422    0.99306  0.663209
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Fuzzing       1.00      0.99      0.99       482
#       Normal       0.98      1.00      0.99     37293
#       Replay       0.00      0.00      0.00       788
#
#     accuracy                           0.98     38563
#    macro avg       0.66      0.66      0.66     38563
# weighted avg       0.96      0.98      0.97     38563
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ================================================================================
#
#
# ================================================================================
#
# Processing ID: 130
# Epoch 1/100
# 362/362 [==============================] - 3s 6ms/step - loss: 0.1890 - accuracy: 0.9743 - val_loss: 0.1040 - val_accuracy: 0.9808
# Epoch 2/100
# 362/362 [==============================] - 3s 8ms/step - loss: 0.1085 - accuracy: 0.9860 - val_loss: 0.0949 - val_accuracy: 0.9811
# Epoch 3/100
# 362/362 [==============================] - 3s 10ms/step - loss: 0.1010 - accuracy: 0.9863 - val_loss: 0.0952 - val_accuracy: 0.9809
# Epoch 4/100
# 362/362 [==============================] - 2s 6ms/step - loss: 0.0938 - accuracy: 0.9864 - val_loss: 0.0929 - val_accuracy: 0.9814
# Epoch 5/100
# 362/362 [==============================] - 2s 6ms/step - loss: 0.1028 - accuracy: 0.9864 - val_loss: 0.0932 - val_accuracy: 0.9815
# Epoch 6/100
# 362/362 [==============================] - 2s 6ms/step - loss: 0.1010 - accuracy: 0.9864 - val_loss: 0.0940 - val_accuracy: 0.9815
# Epoch 7/100
# ...
# Epoch 16/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0590 - accuracy: 0.9926 - val_loss: 0.0614 - val_accuracy: 0.9914
# Epoch 17/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0585 - accuracy: 0.9926 - val_loss: 0.0585 - val_accuracy: 0.9914
# Epoch 18/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0495 - accuracy: 0.9926 - val_loss: 0.0563 - val_accuracy: 0.9914
# Epoch 19/100
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0511 - accuracy: 0.9926 - val_loss: 0.0544 - val_accuracy: 0.9914
# Epoch 20/100
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0478 - accuracy: 0.9926 - val_loss: 0.0529 - val_accuracy: 0.9914
# Epoch 21/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0466 - accuracy: 0.9926 - val_loss: 0.0518 - val_accuracy: 0.9914
# Epoch 22/100
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0478 - accuracy: 0.9926 - val_loss: 0.0507 - val_accuracy: 0.9914
# Epoch 23/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0434 - accuracy: 0.9926 - val_loss: 0.0498 - val_accuracy: 0.9914
# Epoch 24/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0467 - accuracy: 0.9926 - val_loss: 0.0487 - val_accuracy: 0.9914
# Epoch 25/100
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0466 - accuracy: 0.9926 - val_loss: 0.0478 - val_accuracy: 0.9914
# Epoch 26/100
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0441 - accuracy: 0.9926 - val_loss: 0.0472 - val_accuracy: 0.9914
# Epoch 27/100
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0393 - accuracy: 0.9926 - val_loss: 0.0468 - val_accuracy: 0.9914
# Epoch 28/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0429 - accuracy: 0.9926 - val_loss: 0.0465 - val_accuracy: 0.9914
# Epoch 29/100
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0438 - accuracy: 0.9926 - val_loss: 0.0463 - val_accuracy: 0.9914
# Epoch 30/100
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0441 - accuracy: 0.9926 - val_loss: 0.0461 - val_accuracy: 0.9914
# Epoch 31/100
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0417 - accuracy: 0.9926 - val_loss: 0.0459 - val_accuracy: 0.9914
# Epoch 32/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0451 - accuracy: 0.9914 - val_loss: 0.0456 - val_accuracy: 0.9914
# Epoch 33/100
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0432 - accuracy: 0.9926 - val_loss: 0.0455 - val_accuracy: 0.9914
# Epoch 34/100
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0420 - accuracy: 0.9926 - val_loss: 0.0456 - val_accuracy: 0.9914
# Epoch 35/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0426 - accuracy: 0.9926 - val_loss: 0.0460 - val_accuracy: 0.9914
# Epoch 36/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0397 - accuracy: 0.9926 - val_loss: 0.0462 - val_accuracy: 0.9914
# Epoch 37/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0393 - accuracy: 0.9926 - val_loss: 0.0462 - val_accuracy: 0.9914
# Epoch 38/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0426 - accuracy: 0.9926 - val_loss: 0.0460 - val_accuracy: 0.9914
# 41/41 [==============================] - 0s 2ms/step
# Result:
#
#      Accuracy  F1 Score  Precision    Recall
# 07F  0.987597  0.663135    0.99301  0.666667
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Fuzzing       1.00      1.00      1.00       527
#       Normal       0.98      1.00      0.99       747
#       Replay       0.00      0.00      0.00        16
#
#     accuracy                           0.99      1290
#    macro avg       0.66      0.67      0.66      1290
# weighted avg       0.98      0.99      0.98      1290
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ================================================================================
#
#
# ================================================================================
#
# Processing ID: 57F
# Epoch 1/100
# 5/5 [==============================] - 2s 90ms/step - loss: 1.0710 - accuracy: 0.4408 - val_loss: 1.0287 - val_accuracy: 0.3765
# Epoch 2/100
# 5/5 [==============================] - 0s 22ms/step - loss: 1.0024 - accuracy: 0.4930 - val_loss: 0.9473 - val_accuracy: 0.6842
# Epoch 3/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.9181 - accuracy: 0.5279 - val_loss: 0.8429 - val_accuracy: 0.6842
# Epoch 4/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.8295 - accuracy: 0.5575 - val_loss: 0.7428 - val_accuracy: 0.6842
# Epoch 5/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.7574 - accuracy: 0.5749 - val_loss: 0.6767 - val_accuracy: 0.6842
# Epoch 6/100
# 5/5 [==============================] - 0s 20ms/step - loss: 0.7237 - accuracy: 0.5697 - val_loss: 0.6518 - val_accuracy: 0.6842
# Epoch 7/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.7180 - accuracy: 0.5697 - val_loss: 0.6520 - val_accuracy: 0.6842
# Epoch 8/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.7172 - accuracy: 0.5645 - val_loss: 0.6624 - val_accuracy: 0.6842
# Epoch 9/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.7165 - accuracy: 0.5732 - val_loss: 0.6713 - val_accuracy: 0.6842
# Epoch 10/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.7213 - accuracy: 0.5662 - val_loss: 0.6701 - val_accuracy: 0.6842
# Epoch 11/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.7155 - accuracy: 0.5592 - val_loss: 0.6643 - val_accuracy: 0.6842
# 28/28 [==============================] - 0s 3ms/step
# Result:
#
#      Accuracy  F1 Score  Precision    Recall
# 57F  0.579418   0.24457   0.859806  0.333333
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Fuzzing       0.58      1.00      0.73       518
#       Normal       0.00      0.00      0.00       369
#       Replay       0.00      0.00      0.00         7
#
#     accuracy                           0.58       894
#    macro avg       0.19      0.33      0.24       894
# weighted avg       0.34      0.58      0.43       894
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ================================================================================
#
#
# ================================================================================
#
# Processing ID: 5B0
# Epoch 1/100
# 7/7 [==============================] - 2s 76ms/step - loss: 1.0525 - accuracy: 0.7365 - val_loss: 0.9453 - val_accuracy: 0.9914
# Epoch 2/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.9251 - accuracy: 0.9926 - val_loss: 0.7734 - val_accuracy: 0.9914
# Epoch 3/100
# 7/7 [==============================] - 0s 20ms/step - loss: 0.7709 - accuracy: 0.9926 - val_loss: 0.5762 - val_accuracy: 0.9914
# Epoch 4/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.6182 - accuracy: 0.9926 - val_loss: 0.4356 - val_accuracy: 0.9914
# Epoch 5/100
# 7/7 [==============================] - 0s 19ms/step - loss: 0.
100
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0407 - accuracy: 0.9926 - val_loss: 0.0447 - val_accuracy: 0.9914
# Epoch 37/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0415 - accuracy: 0.9926 - val_loss: 0.0446 - val_accuracy: 0.9914
# Epoch 38/100
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0413 - accuracy: 0.9926 - val_loss: 0.0445 - val_accuracy: 0.9914
# Epoch 39/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0422 - accuracy: 0.9926 - val_loss: 0.0444 - val_accuracy: 0.9914
# Epoch 40/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0411 - accuracy: 0.9926 - val_loss: 0.0444 - val_accuracy: 0.9914
# Epoch 41/100
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0398 - accuracy: 0.9926 - val_loss: 0.0448 - val_accuracy: 0.9914
# Epoch 42/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0464 - accuracy: 0.9926 - val_loss: 0.0447 - val_accuracy: 0.9914
# Epoch 43/100
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0402 - accuracy: 0.9926 - val_loss: 0.0446 - val_accuracy: 0.9914
# Epoch 44/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0426 - accuracy: 0.9926 - val_loss: 0.0445 - val_accuracy: 0.9914
# 40/40 [==============================] - 0s 3ms/step
# Result:
#
#      Accuracy  F1 Score  Precision    Recall
# 5B0  0.988057   0.66334   0.993412  0.666667
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Fuzzing       1.00      1.00      1.00       497
#       Normal       0.98      1.00      0.99       744
#       Replay       0.00      0.00      0.00        15
#
#     accuracy                           0.99      1256
#    macro avg       0.66      0.67      0.66      1256
# weighted avg       0.98      0.99      0.98      1256
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ================================================================================
#
#
# ================================================================================

# %% [markdown]
# ### 모든 ID들의 성능의 평균치 계산
# - Accuracy, F1-score, Precision의 평균 계산

# %%
id_total_results
# Out:
#                 251       2B0       381       340       260       47F  \
# Accuracy   0.979334  0.979616  0.979563  0.979482  0.999987  0.979557
# F1 Score   0.659547  0.663187  0.662539  0.663188  0.999826  0.662517
# Precision  0.992085  0.993112  0.993095  0.993115  0.999996  0.993096
# Recall     0.660457  0.666667  0.665392  0.666667  0.999656  0.665347
#
#                 329       164       387       394  ...       4A2       50A  \
# Accuracy   0.979399  0.979612  0.976477  0.979538  ...  0.984260  0.984364
# F1 Score   0.661867  0.663187  0.741338  0.662811  ...  0.663121  0.661490
# Precision  0.993087  0.993113  0.780321  0.993099  ...  0.992982  0.994257
# Recall     0.664062  0.666667  0.721368  0.665929  ...  0.666667  0.662136
#
#                 043       52A       544       559       410       07F  \
# Accuracy   0.993096  0.986878  0.979355  0.981438  0.981780  0.987597
# F1 Score   0.843498  0.664342  0.659444  0.663163  0.663170  0.663135
# Precision  0.994730  0.995383  0.992209  0.993065  0.993079  0.993010
# Recall     0.789474  0.666667  0.660169  0.666667  0.666667  0.666667
#
#                 57F       5B0
# Accuracy   0.579418  0.988057
# F1 Score   0.244570  0.663340
# Precision  0.859806  0.993412
# Recall     0.333333  0.666667
#
# [4 rows x 53 columns]

# %%
id_total_results.mean(axis='columns')
# Out:
# Accuracy     0.952117
# F1 Score     0.647139
# Precision    0.973972
# Recall       0.657867
# dtype: float64

# %%
output_file = '/content/drive/MyDrive/CAN/submit_filter_data/ANN_performance_scores_by_id_v2_macro.csv'
id_total_results.to_csv(output_file, index=False)
